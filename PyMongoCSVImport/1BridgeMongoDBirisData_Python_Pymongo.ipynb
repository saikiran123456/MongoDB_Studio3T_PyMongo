# %% [markdown]
# ## 3. Pymongo Module in Python:

# %% [markdown]
# let’s explore how to bridge the MongoDB data and Python using pymongo.
#
# To install the module, you need to simply write
# **pip install pymongo in your conda terminal**

# %%
# Import the library
import pymongo

# %%
# Getting the access to local MongoDB databases
databases = pymongo.MongoClient()

# %%
# Getting the access to `admin` database from the group of other databases present
admin_db = databases.admin

# %%
# Getting the access to 'Tutorial' collection that we just created inside `admin` database
tutorial_collection = admin_db.DataAnalysisVidhya

# %%
# Now this is where our imported `iris` data is stored. 
#To fetch one entry/record/document from the collection we can write:
tutorial_collection.find_one({})
# Out:
# {'_id': ObjectId('639962e1962d29d48eb20649'),
#  '': 1,
#  'Sepal': {'Length': '5.1', 'Width': '3.5'},
#  'Petal': {'Length': '1.4', 'Width': '0.2'},
#  'Species': 'setosa'}

# %%
tutorial_collection.find({})

# %% [markdown]
# **Note: pymongo cursor object is iterable, so here we converted it into a list to glance at all the values.**

# %%
list(tutorial_collection.find({}))
# Out:
# [{'_id': ObjectId('639962e1962d29d48eb20649'),
#   '': 1,
#   'Sepal': {'Length': '5.1', 'Width': '3.5'},
#   'Petal': {'Length': '1.4', 'Width': '0.2'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb2064a'),
#   '': 2,
#   'Sepal': {'Length': '4.9', 'Width': '3'},
#   'Petal': {'Length': '1.4', 'Width': '0.2'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb2064b'),
#   '': 3,
#   'Sepal': {'Length': '4.7', 'Width': '3.2'},
#   'Petal': {'Length': '1.3', 'Width': '0.2'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb2064c'),
#   '': 4,
#   'Sepal': {'Length': '4.6', 'Width': '3.1'},
#   'Petal': {'Length': '1.5', 'Width': '0.2'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb2064d'),
#   '': 5,
#   'Sepal': {'Length': '5', 'Width': '3.6'},
#   'Petal': {'Length': '1.4', 'Width': '0.2'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb2064e'),
#   '': 6,
#   'Sepal': {'Length': '5.4', 'Width': '3.9'},
#   'Petal': {'Length': '1.7', 'Width': '0.4'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb2064f'),
#   '': 7,
#   'Sepal': {'Length': '4.6', 'Width': '3.4'},
#   'Petal': {'Length': '1.4', 'Width': '0.3'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb20650'),
#   '': 8,
#   'Sepal': {'Length': '5', 'Width': '3.4'},
#   'Petal': {'Length': '1.5', 'Width': '0.2'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb20651'),
#   '': 9,
#   'Sepal': {'Length': '4.4', 'Width': '2.9'},
#   'Petal': {'Length': '1.4', 'Width': '0.2'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb20652'),
#   '': 10,
#   'Sepal': {'Length': '4.9', 'Width': '3.1'},
#   'Petal': {'Length': '1.5', 'Width': '0.1'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb20653'),
#   '': 11,
#   'Sepal': {'Length': '5.4', 'Width': '3.7'},
#   'Petal': {'Length': '1.5', 'Width': '0.2'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb20654'),
#   '': 12,
#   'Sepal': {'Length': '4.8', 'Width': '3.4'},
#   'Petal': {'Length': '1.6', 'Width': '0.2'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb20655'),
#   '': 13,
#   'Sepal': {'Length': '4.8', 'Width': '3'},
#   'Petal': {'Length': '1.4', 'Width': '0.1'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb20656'),
#   '': 14,
#   'Sepal': {'Length': '4.3', 'Width': '3'},
#   'Petal': {'Length': '1.1', 'Width': '0.1'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb20657'),
#   '': 15,
#   'Sepal': {'Length': '5.8', 'Width': '4'},
#   'Petal': {'Length': '1.2', 'Width': '0.2'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb20658'),
#   '': 16,
#   'Sepal': {'Length': '5.7', 'Width': '4.4'},
#   'Petal': {'Length': '1.5', 'Width': '0.4'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb20659'),
#   '': 17,
#   'Sepal': {'Length': '5.4', 'Width': '3.9'},
#   'Petal': {'Length': '1.3', 'Width': '0.4'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb2065a'),
#   '': 18,
#   'Sepal': {'Length': '5.1', 'Width': '3.5'},
#   'Petal': {'Length': '1.4', 'Width': '0.3'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb2065b'),
#   '': 19,
#   'Sepal': {'Length': '5.7', 'Width': '3.8'},
#   'Petal': {'Length': '1.7', 'Width': '0.3'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb2065c'),
#   '': 20,
#   'Sepal': {'Length': '5.1', 'Width': '3.8'},
#   'Petal': {'Length': '1.5', 'Width': '0.3'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb2065d'),
#   '': 21,
#   'Sepal': {'Length': '5.4', 'Width': '3.4'},
#   'Petal': {'Length': '1.7', 'Width': '0.2'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb2065e'),
#   '': 22,
#   'Sepal': {'Length': '5.1', 'Width': '3.7'},
#   'Petal': {'Length': '1.5', 'Width': '0.4'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb2065f'),
#   '': 23,
#   'Sepal': {'Length': '4.6', 'Width': '3.6'},
#   'Petal': {'Length': '1', 'Width': '0.2'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb20660'),
#   '': 24,
#   'Sepal': {'Length': '5.1', 'Width': '3.3'},
#   'Petal': {'Length': '1.7', 'Width': '0.5'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb20661'),
#   '': 25,
#   'Sepal': {'Length': '4.8', 'Width': '3.4'},
#   'Petal': {'Length': '1.9', 'Width': '0.2'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb20662'),
#   '': 26,
#   'Sepal': {'Length': '5', 'Width': '3'},
#   'Petal': {'Length': '1.6', 'Width': '0.2'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb20663'),
#   '': 27,
#   'Sepal': {'Length': '5', 'Width': '3.4'},
#   'Petal': {'Length': '1.6', 'Width': '0.4'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb20664'),
#   '': 28,
#   'Sepal': {'Length': '5.2', 'Width': '3.5'},
#   'Petal': {'Length': '1.5', 'Width': '0.2'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb20665'),
#   '': 29,
#   'Sepal': {'Length': '5.2', 'Width': '3.4'},
#   'Petal': {'Length': '1.4', 'Width': '0.2'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb20666'),
#   '': 30,
#   'Sepal': {'Length': '4.7', 'Width': '3.2'},
#   'Petal': {'Length': '1.6', 'Width': '0.2'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb20667'),
#   '': 31,
#   'Sepal': {'Length': '4.8', 'Width': '3.1'},
#   'Petal': {'Length': '1.6', 'Width': '0.2'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb20668'),
#   '': 32,
#   'Sepal': {'Length': '5.4', 'Width': '3.4'},
#   'Petal': {'Length': '1.5', 'Width': '0.4'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb20669'),
#   '': 33,
#   'Sepal': {'Length': '5.2', 'Width': '4.1'},
#   'Petal': {'Length': '1.5', 'Width': '0.1'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb2066a'),
#   '': 34,
#   'Sepal': {'Length': '5.5', 'Width': '4.2'},
#   'Petal': {'Length': '1.4', 'Width': '0.2'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb2066b'),
#   '': 35,
#   'Sepal': {'Length': '4.9', 'Width': '3.1'},
#   'Petal': {'Length': '1.5', 'Width': '0.2'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb2066c'),
#   '': 36,
#   'Sepal': {'Length': '5', 'Width': '3.2'},
#   'Petal': {'Length': '1.2', 'Width': '0.2'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb2066d'),
#   '': 37,
#   'Sepal': {'Length': '5.5', 'Width': '3.5'},
#   'Petal': {'Length': '1.3', 'Width': '0.2'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb2066e'),
#   '': 38,
#   'Sepal': {'Length': '4.9', 'Width': '3.6'},
#   'Petal': {'Length': '1.4', 'Width': '0.1'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb2066f'),
#   '': 39,
#   'Sepal': {'Length': '4.4', 'Width': '3'},
#   'Petal': {'Length': '1.3', 'Width': '0.2'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb20670'),
#   '': 40,
#   'Sepal': {'Length': '5.1', 'Width': '3.4'},
#   'Petal': {'Length': '1.5', 'Width': '0.2'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb20671'),
#   '': 41,
#   'Sepal': {'Length': '5', 'Width': '3.5'},
#   'Petal': {'Length': '1.3', 'Width': '0.3'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb20672'),
#   '': 42,
#   'Sepal': {'Length': '4.5', 'Width': '2.3'},
#   'Petal': {'Length': '1.3', 'Width': '0.3'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb20673'),
#   '': 43,
#   'Sepal': {'Length': '4.4', 'Width': '3.2'},
#   'Petal': {'Length': '1.3', 'Width': '0.2'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb20674'),
#   '': 44,
#   'Sepal': {'Length': '5', 'Width': '3.5'},
#   'Petal': {'Length': '1.6', 'Width': '0.6'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb20675'),
#   '': 45,
#   'Sepal': {'Length': '5.1', 'Width': '3.8'},
#   'Petal': {'Length': '1.9', 'Width': '0.4'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb20676'),
#   '': 46,
#   'Sepal': {'Length': '4.8', 'Width': '3'},
#   'Petal': {'Length': '1.4', 'Width': '0.3'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb20677'),
#   '': 47,
#   'Sepal': {'Length': '5.1', 'Width': '3.8'},
#   'Petal': {'Length': '1.6', 'Width': '0.2'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb20678'),
#   '': 48,
#   'Sepal': {'Length': '4.6', 'Width': '3.2'},
#   'Petal': {'Length': '1.4', 'Width': '0.2'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb20679'),
#   '': 49,
#   'Sepal': {'Length': '5.3', 'Width': '3.7'},
#   'Petal': {'Length': '1.5', 'Width': '0.2'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb2067a'),
#   '': 50,
#   'Sepal': {'Length': '5', 'Width': '3.3'},
#   'Petal': {'Length': '1.4', 'Width': '0.2'},
#   'Species': 'setosa'},
#  {'_id': ObjectId('639962e1962d29d48eb2067b'),
#   '': 51,
#   'Sepal': {'Length': '7', 'Width': '3.2'},
#   'Petal': {'Length': '4.7', 'Width': '1.4'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb2067c'),
#   '': 52,
#   'Sepal': {'Length': '6.4', 'Width': '3.2'},
#   'Petal': {'Length': '4.5', 'Width': '1.5'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb2067d'),
#   '': 53,
#   'Sepal': {'Length': '6.9', 'Width': '3.1'},
#   'Petal': {'Length': '4.9', 'Width': '1.5'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb2067e'),
#   '': 54,
#   'Sepal': {'Length': '5.5', 'Width': '2.3'},
#   'Petal': {'Length': '4', 'Width': '1.3'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb2067f'),
#   '': 55,
#   'Sepal': {'Length': '6.5', 'Width': '2.8'},
#   'Petal': {'Length': '4.6', 'Width': '1.5'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb20680'),
#   '': 56,
#   'Sepal': {'Length': '5.7', 'Width': '2.8'},
#   'Petal': {'Length': '4.5', 'Width': '1.3'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb20681'),
#   '': 57,
#   'Sepal': {'Length': '6.3', 'Width': '3.3'},
#   'Petal': {'Length': '4.7', 'Width': '1.6'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb20682'),
#   '': 58,
#   'Sepal': {'Length': '4.9', 'Width': '2.4'},
#   'Petal': {'Length': '3.3', 'Width': '1'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb20683'),
#   '': 59,
#   'Sepal': {'Length': '6.6', 'Width': '2.9'},
#   'Petal': {'Length': '4.6', 'Width': '1.3'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb20684'),
#   '': 60,
#   'Sepal': {'Length': '5.2', 'Width': '2.7'},
#   'Petal': {'Length': '3.9', 'Width': '1.4'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb20685'),
#   '': 61,
#   'Sepal': {'Length': '5', 'Width': '2'},
#   'Petal': {'Length': '3.5', 'Width': '1'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb20686'),
#   '': 62,
#   'Sepal': {'Length': '5.9', 'Width': '3'},
#   'Petal': {'Length': '4.2', 'Width': '1.5'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb20687'),
#   '': 63,
#   'Sepal': {'Length': '6', 'Width': '2.2'},
#   'Petal': {'Length': '4', 'Width': '1'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb20688'),
#   '': 64,
#   'Sepal': {'Length': '6.1', 'Width': '2.9'},
#   'Petal': {'Length': '4.7', 'Width': '1.4'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb20689'),
#   '': 65,
#   'Sepal': {'Length': '5.6', 'Width': '2.9'},
#   'Petal': {'Length': '3.6', 'Width': '1.3'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb2068a'),
#   '': 66,
#   'Sepal': {'Length': '6.7', 'Width': '3.1'},
#   'Petal': {'Length': '4.4', 'Width': '1.4'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb2068b'),
#   '': 67,
#   'Sepal': {'Length': '5.6', 'Width': '3'},
#   'Petal': {'Length': '4.5', 'Width': '1.5'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb2068c'),
#   '': 68,
#   'Sepal': {'Length': '5.8', 'Width': '2.7'},
#   'Petal': {'Length': '4.1', 'Width': '1'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb2068d'),
#   '': 69,
#   'Sepal': {'Length': '6.2', 'Width': '2.2'},
#   'Petal': {'Length': '4.5', 'Width': '1.5'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb2068e'),
#   '': 70,
#   'Sepal': {'Length': '5.6', 'Width': '2.5'},
#   'Petal': {'Length': '3.9', 'Width': '1.1'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb2068f'),
#   '': 71,
#   'Sepal': {'Length': '5.9', 'Width': '3.2'},
#   'Petal': {'Length': '4.8', 'Width': '1.8'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb20690'),
#   '': 72,
#   'Sepal': {'Length': '6.1', 'Width': '2.8'},
#   'Petal': {'Length': '4', 'Width': '1.3'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb20691'),
#   '': 73,
#   'Sepal': {'Length': '6.3', 'Width': '2.5'},
#   'Petal': {'Length': '4.9', 'Width': '1.5'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb20692'),
#   '': 74,
#   'Sepal': {'Length': '6.1', 'Width': '2.8'},
#   'Petal': {'Length': '4.7', 'Width': '1.2'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb20693'),
#   '': 75,
#   'Sepal': {'Length': '6.4', 'Width': '2.9'},
#   'Petal': {'Length': '4.3', 'Width': '1.3'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb20694'),
#   '': 76,
#   'Sepal': {'Length': '6.6', 'Width': '3'},
#   'Petal': {'Length': '4.4', 'Width': '1.4'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb20695'),
#   '': 77,
#   'Sepal': {'Length': '6.8', 'Width': '2.8'},
#   'Petal': {'Length': '4.8', 'Width': '1.4'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb20696'),
#   '': 78,
#   'Sepal': {'Length': '6.7', 'Width': '3'},
#   'Petal': {'Length': '5', 'Width': '1.7'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb20697'),
#   '': 79,
#   'Sepal': {'Length': '6', 'Width': '2.9'},
#   'Petal': {'Length': '4.5', 'Width': '1.5'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb20698'),
#   '': 80,
#   'Sepal': {'Length': '5.7', 'Width': '2.6'},
#   'Petal': {'Length': '3.5', 'Width': '1'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb20699'),
#   '': 81,
#   'Sepal': {'Length': '5.5', 'Width': '2.4'},
#   'Petal': {'Length': '3.8', 'Width': '1.1'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb2069a'),
#   '': 82,
#   'Sepal': {'Length': '5.5', 'Width': '2.4'},
#   'Petal': {'Length': '3.7', 'Width': '1'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb2069b'),
#   '': 83,
#   'Sepal': {'Length': '5.8', 'Width': '2.7'},
#   'Petal': {'Length': '3.9', 'Width': '1.2'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb2069c'),
#   '': 84,
#   'Sepal': {'Length': '6', 'Width': '2.7'},
#   'Petal': {'Length': '5.1', 'Width': '1.6'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb2069d'),
#   '': 85,
#   'Sepal': {'Length': '5.4', 'Width': '3'},
#   'Petal': {'Length': '4.5', 'Width': '1.5'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb2069e'),
#   '': 86,
#   'Sepal': {'Length': '6', 'Width': '3.4'},
#   'Petal': {'Length': '4.5', 'Width': '1.6'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb2069f'),
#   '': 87,
#   'Sepal': {'Length': '6.7', 'Width': '3.1'},
#   'Petal': {'Length': '4.7', 'Width': '1.5'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb206a0'),
#   '': 88,
#   'Sepal': {'Length': '6.3', 'Width': '2.3'},
#   'Petal': {'Length': '4.4', 'Width': '1.3'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb206a1'),
#   '': 89,
#   'Sepal': {'Length': '5.6', 'Width': '3'},
#   'Petal': {'Length': '4.1', 'Width': '1.3'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb206a2'),
#   '': 90,
#   'Sepal': {'Length': '5.5', 'Width': '2.5'},
#   'Petal': {'Length': '4', 'Width': '1.3'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb206a3'),
#   '': 91,
#   'Sepal': {'Length': '5.5', 'Width': '2.6'},
#   'Petal': {'Length': '4.4', 'Width': '1.2'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb206a4'),
#   '': 92,
#   'Sepal': {'Length': '6.1', 'Width': '3'},
#   'Petal': {'Length': '4.6', 'Width': '1.4'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb206a5'),
#   '': 93,
#   'Sepal': {'Length': '5.8', 'Width': '2.6'},
#   'Petal': {'Length': '4', 'Width': '1.2'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb206a6'),
#   '': 94,
#   'Sepal': {'Length': '5', 'Width': '2.3'},
#   'Petal': {'Length': '3.3', 'Width': '1'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb206a7'),
#   '': 95,
#   'Sepal': {'Length': '5.6', 'Width': '2.7'},
#   'Petal': {'Length': '4.2', 'Width': '1.3'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb206a8'),
#   '': 96,
#   'Sepal': {'Length': '5.7', 'Width': '3'},
#   'Petal': {'Length': '4.2', 'Width': '1.2'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb206a9'),
#   '': 97,
#   'Sepal': {'Length': '5.7', 'Width': '2.9'},
#   'Petal': {'Length': '4.2', 'Width': '1.3'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb206aa'),
#   '': 98,
#   'Sepal': {'Length': '6.2', 'Width': '2.9'},
#   'Petal': {'Length': '4.3', 'Width': '1.3'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb206ab'),
#   '': 99,
#   'Sepal': {'Length': '5.1', 'Width': '2.5'},
#   'Petal': {'Length': '3', 'Width': '1.1'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb206ac'),
#   '': 100,
#   'Sepal': {'Length': '5.7', 'Width': '2.8'},
#   'Petal': {'Length': '4.1', 'Width': '1.3'},
#   'Species': 'versicolor'},
#  {'_id': ObjectId('639962e1962d29d48eb206ad'),
#   '': 101,
#   'Sepal': {'Length': '6.3', 'Width': '3.3'},
#   'Petal': {'Length': '6', 'Width': '2.5'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206ae'),
#   '': 102,
#   'Sepal': {'Length': '5.8', 'Width': '2.7'},
#   'Petal': {'Length': '5.1', 'Width': '1.9'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206af'),
#   '': 103,
#   'Sepal': {'Length': '7.1', 'Width': '3'},
#   'Petal': {'Length': '5.9', 'Width': '2.1'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206b0'),
#   '': 104,
#   'Sepal': {'Length': '6.3', 'Width': '2.9'},
#   'Petal': {'Length': '5.6', 'Width': '1.8'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206b1'),
#   '': 105,
#   'Sepal': {'Length': '6.5', 'Width': '3'},
#   'Petal': {'Length': '5.8', 'Width': '2.2'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206b2'),
#   '': 106,
#   'Sepal': {'Length': '7.6', 'Width': '3'},
#   'Petal': {'Length': '6.6', 'Width': '2.1'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206b3'),
#   '': 107,
#   'Sepal': {'Length': '4.9', 'Width': '2.5'},
#   'Petal': {'Length': '4.5', 'Width': '1.7'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206b4'),
#   '': 108,
#   'Sepal': {'Length': '7.3', 'Width': '2.9'},
#   'Petal': {'Length': '6.3', 'Width': '1.8'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206b5'),
#   '': 109,
#   'Sepal': {'Length': '6.7', 'Width': '2.5'},
#   'Petal': {'Length': '5.8', 'Width': '1.8'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206b6'),
#   '': 110,
#   'Sepal': {'Length': '7.2', 'Width': '3.6'},
#   'Petal': {'Length': '6.1', 'Width': '2.5'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206b7'),
#   '': 111,
#   'Sepal': {'Length': '6.5', 'Width': '3.2'},
#   'Petal': {'Length': '5.1', 'Width': '2'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206b8'),
#   '': 112,
#   'Sepal': {'Length': '6.4', 'Width': '2.7'},
#   'Petal': {'Length': '5.3', 'Width': '1.9'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206b9'),
#   '': 113,
#   'Sepal': {'Length': '6.8', 'Width': '3'},
#   'Petal': {'Length': '5.5', 'Width': '2.1'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206ba'),
#   '': 114,
#   'Sepal': {'Length': '5.7', 'Width': '2.5'},
#   'Petal': {'Length': '5', 'Width': '2'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206bb'),
#   '': 115,
#   'Sepal': {'Length': '5.8', 'Width': '2.8'},
#   'Petal': {'Length': '5.1', 'Width': '2.4'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206bc'),
#   '': 116,
#   'Sepal': {'Length': '6.4', 'Width': '3.2'},
#   'Petal': {'Length': '5.3', 'Width': '2.3'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206bd'),
#   '': 117,
#   'Sepal': {'Length': '6.5', 'Width': '3'},
#   'Petal': {'Length': '5.5', 'Width': '1.8'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206be'),
#   '': 118,
#   'Sepal': {'Length': '7.7', 'Width': '3.8'},
#   'Petal': {'Length': '6.7', 'Width': '2.2'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206bf'),
#   '': 119,
#   'Sepal': {'Length': '7.7', 'Width': '2.6'},
#   'Petal': {'Length': '6.9', 'Width': '2.3'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206c0'),
#   '': 120,
#   'Sepal': {'Length': '6', 'Width': '2.2'},
#   'Petal': {'Length': '5', 'Width': '1.5'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206c1'),
#   '': 121,
#   'Sepal': {'Length': '6.9', 'Width': '3.2'},
#   'Petal': {'Length': '5.7', 'Width': '2.3'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206c2'),
#   '': 122,
#   'Sepal': {'Length': '5.6', 'Width': '2.8'},
#   'Petal': {'Length': '4.9', 'Width': '2'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206c3'),
#   '': 123,
#   'Sepal': {'Length': '7.7', 'Width': '2.8'},
#   'Petal': {'Length': '6.7', 'Width': '2'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206c4'),
#   '': 124,
#   'Sepal': {'Length': '6.3', 'Width': '2.7'},
#   'Petal': {'Length': '4.9', 'Width': '1.8'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206c5'),
#   '': 125,
#   'Sepal': {'Length': '6.7', 'Width': '3.3'},
#   'Petal': {'Length': '5.7', 'Width': '2.1'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206c6'),
#   '': 126,
#   'Sepal': {'Length': '7.2', 'Width': '3.2'},
#   'Petal': {'Length': '6', 'Width': '1.8'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206c7'),
#   '': 127,
#   'Sepal': {'Length': '6.2', 'Width': '2.8'},
#   'Petal': {'Length': '4.8', 'Width': '1.8'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206c8'),
#   '': 128,
#   'Sepal': {'Length': '6.1', 'Width': '3'},
#   'Petal': {'Length': '4.9', 'Width': '1.8'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206c9'),
#   '': 129,
#   'Sepal': {'Length': '6.4', 'Width': '2.8'},
#   'Petal': {'Length': '5.6', 'Width': '2.1'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206ca'),
#   '': 130,
#   'Sepal': {'Length': '7.2', 'Width': '3'},
#   'Petal': {'Length': '5.8', 'Width': '1.6'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206cb'),
#   '': 131,
#   'Sepal': {'Length': '7.4', 'Width': '2.8'},
#   'Petal': {'Length': '6.1', 'Width': '1.9'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206cc'),
#   '': 132,
#   'Sepal': {'Length': '7.9', 'Width': '3.8'},
#   'Petal': {'Length': '6.4', 'Width': '2'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206cd'),
#   '': 133,
#   'Sepal': {'Length': '6.4', 'Width': '2.8'},
#   'Petal': {'Length': '5.6', 'Width': '2.2'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206ce'),
#   '': 134,
#   'Sepal': {'Length': '6.3', 'Width': '2.8'},
#   'Petal': {'Length': '5.1', 'Width': '1.5'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206cf'),
#   '': 135,
#   'Sepal': {'Length': '6.1', 'Width': '2.6'},
#   'Petal': {'Length': '5.6', 'Width': '1.4'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206d0'),
#   '': 136,
#   'Sepal': {'Length': '7.7', 'Width': '3'},
#   'Petal': {'Length': '6.1', 'Width': '2.3'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206d1'),
#   '': 137,
#   'Sepal': {'Length': '6.3', 'Width': '3.4'},
#   'Petal': {'Length': '5.6', 'Width': '2.4'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206d2'),
#   '': 138,
#   'Sepal': {'Length': '6.4', 'Width': '3.1'},
#   'Petal': {'Length': '5.5', 'Width': '1.8'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206d3'),
#   '': 139,
#   'Sepal': {'Length': '6', 'Width': '3'},
#   'Petal': {'Length': '4.8', 'Width': '1.8'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206d4'),
#   '': 140,
#   'Sepal': {'Length': '6.9', 'Width': '3.1'},
#   'Petal': {'Length': '5.4', 'Width': '2.1'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206d5'),
#   '': 141,
#   'Sepal': {'Length': '6.7', 'Width': '3.1'},
#   'Petal': {'Length': '5.6', 'Width': '2.4'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206d6'),
#   '': 142,
#   'Sepal': {'Length': '6.9', 'Width': '3.1'},
#   'Petal': {'Length': '5.1', 'Width': '2.3'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206d7'),
#   '': 143,
#   'Sepal': {'Length': '5.8', 'Width': '2.7'},
#   'Petal': {'Length': '5.1', 'Width': '1.9'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206d8'),
#   '': 144,
#   'Sepal': {'Length': '6.8', 'Width': '3.2'},
#   'Petal': {'Length': '5.9', 'Width': '2.3'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206d9'),
#   '': 145,
#   'Sepal': {'Length': '6.7', 'Width': '3.3'},
#   'Petal': {'Length': '5.7', 'Width': '2.5'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206da'),
#   '': 146,
#   'Sepal': {'Length': '6.7', 'Width': '3'},
#   'Petal': {'Length': '5.2', 'Width': '2.3'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206db'),
#   '': 147,
#   'Sepal': {'Length': '6.3', 'Width': '2.5'},
#   'Petal': {'Length': '5', 'Width': '1.9'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206dc'),
#   '': 148,
#   'Sepal': {'Length': '6.5', 'Width': '3'},
#   'Petal': {'Length': '5.2', 'Width': '2'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206dd'),
#   '': 149,
#   'Sepal': {'Length': '6.2', 'Width': '3.4'},
#   'Petal': {'Length': '5.4', 'Width': '2.3'},
#   'Species': 'virginica'},
#  {'_id': ObjectId('639962e1962d29d48eb206de'),
#   '': 150,
#   'Sepal': {'Length': '5.9', 'Width': '3'},
#   'Petal': {'Length': '5.1', 'Width': '1.8'},
#   'Species': 'virginica'}]

# %% [markdown]
# the list goes on till all the 150 values of the iris dataset.

# %% [markdown]
# ## 4. Getting ready for Data Science analysis!!

# %% [markdown]
# We are onto the final stage that would join my blog to further down the line data science/ Analytics tasks.

# %% [markdown]
# We need to create a DataFrame using pandas for our MongoDB Tutorial Collection.

# %% [markdown]
# ### Jupyter notebooks for better interactivity.

# %%
import pandas as pd

iris_df = pd.DataFrame(list(tutorial_collection.find({})))
iris_df
# Out:
#                           _id                                   Sepal  \
# 0    639962e1962d29d48eb20649    1  {'Length': '5.1', 'Width': '3.5'}
# 1    639962e1962d29d48eb2064a    2    {'Length': '4.9', 'Width': '3'}
# 2    639962e1962d29d48eb2064b    3  {'Length': '4.7', 'Width': '3.2'}
# 3    639962e1962d29d48eb2064c    4  {'Length': '4.6', 'Width': '3.1'}
# 4    639962e1962d29d48eb2064d    5    {'Length': '5', 'Width': '3.6'}
# ..                        ...  ...                                ...
# 145  639962e1962d29d48eb206da  146    {'Length': '6.7', 'Width': '3'}
# 146  639962e1962d29d48eb206db  147  {'Length': '6.3', 'Width': '2.5'}
# 147  639962e1962d29d48eb206dc  148    {'Length': '6.5', 'Width': '3'}
# 148  639962e1962d29d48eb206dd  149  {'Length': '6.2', 'Width': '3.4'}
# 149  639962e1962d29d48eb206de  150    {'Length': '5.9', 'Width': '3'}
#
#                                  Petal    Species
# 0    {'Length': '1.4', 'Width': '0.2'}     setosa
# 1    {'Length': '1.4', 'Width': '0.2'}     setosa
# 2    {'Length': '1.3', 'Width': '0.2'}     setosa
# 3    {'Length': '1.5', 'Width': '0.2'}     setosa
# 4    {'Length': '1.4', 'Width': '0.2'}     setosa
# ..                                 ...        ...
# 145  {'Length': '5.2', 'Width': '2.3'}  virginica
# 146    {'Length': '5', 'Width': '1.9'}  virginica
# 147    {'Length': '5.2', 'Width': '2'}  virginica
# 148  {'Length': '5.4', 'Width': '2.3'}  virginica
# 149  {'Length': '5.1', 'Width': '1.8'}  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# **If you don’t want some of the columns you can clean them in 2 ways:**

# %% [markdown]
# * First is before retrieving the data from database to python code using MongoDB aggregate pipelines(Out of the scope as of now)
#
# * The second is data cleaning after creating the DataFrame of the data.

# %%
# we will clear the 'id' columns by second approach,
iris_df = iris_df.drop("_id", axis=1)
# iris_df.head()

# %% [markdown]
# **Now further down the line, you can write the same code as any other data science/analytics task.**

# %% [markdown]
# From this point onwards, you can be as flexible as would want with your data science skills.
